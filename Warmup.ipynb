# %% [markdown]
# # DISPLAYING INFORMATION

# %%
def display_board(row1,row2,row3):
    row1 = ['','','']
    row2 = ['','','']
    row3 = ['','','']

# %%
position_index = int(input("Choose an index posiition"))

# %%
row1 = [position_index]

# %%
row1

display_board(row1)

# %% [markdown]
# # SIMPLE GAME

# %%
game_list =[0,1,2]

# %%
def display_game(game_list):
    print("Here is the current list: ")
    print(game_list)

# %%
def position_choice():

    choice = 'wrong'
    
    while choice not in ['0','1','2']:
        choice = input("Pick a position (0,1,2):")
        if choice not in ['0','1','2']:
            print("sorry , Invalid Choice!")

    return int(choice)

# %%
def replacement_choice(game_list,position):
    user_placement = input("Type a string to place at position")
    game_list[position] = user_placement
    return game_list

# %%
def gameon_choice():
    choice = 'WRONG'
    while choice not in ['Y','N']:
        choice = input("Keep playing(Y/N)")

        if choice not in ['Y','N']:
            print("Sorry.. Choose Y/N")

    if choice == 'Y':
        return True
    else:
        return False

# %%
game_on = True
game_list = [0,1,2]

while game_on:
    display_game(game_list)
    position = position_choice()
    game_list = replacement_choice(game_list,position)
    display_game(game_list)
    game_on = gameon_choice()

# %% [markdown]
# # D E C O R A T O R

# %%
## Now lets do it with Decorator function.
import time
from datetime import datetime,timedelta

def time_decor(base_fn):
    def enhanced_fn(*args,**kwarg):
        start_time = time.time()
        result = base_fn(*args,**kwarg)
        end_time = time.time()
        print(f"Task time: {end_time - start_time} sec")
        return result
    return enhanced_fn


@time_decor
def brew_tea(tea_type,steep_time):
    print(f"Brewing ..{tea_type}")
    time.sleep(steep_time)
    print(f"{tea_type} is Ready!")


@time_decor
def brew_motcha():
    print("Making Motcha")
    time.sleep(2)
    print("Motcha is Ready!")
    return f"Drink Motcha by {datetime.now() + timedelta(minutes=30)}"

# %%
brew_tea("Irani Chai",1)
print(brew_motcha())
# Out:
# Brewing ..Irani Chai
# Irani Chai is Ready!
# Task time: 1.0004844665527344 sec
# Making Motcha
# Motcha is Ready!
# Task time: 2.005610942840576 sec
# Drink Motcha by 2025-11-28 22:36:29.676631

# %%
from IPython.display import clear_output

def display_board(board):
    print(board[1]+'|'+board[2]+'|'+board[3])
    print(board[4]+'|'+board[5]+'|'+board[6])
    print(board[7]+'|'+board[8]+'|'+board[9])

# %%
test_board = ['#','X','O','X','O','X','O','X','O','X']
display_board(test_board)
# Out:
# X|O|X
# O|X|O
# X|O|X

# %%
def pridiscount():
    for p in prices:
        print (p * (1-discount))



discount = 0.10
prices = [12.3,23.56,22.00,3.00,45.90]
result = pridiscount()
print(result)

# %% [markdown]
# # Error Handling / Exception Handling

# %%
try:

    numerator = float(input("Enter Numerator:"))
    denominator = float(input("Enter denominator:"))
    quotient = numerator / denominator
    print(f"The quotient is {quotient}.")
except ValueError:
    print("Invalid input")
except ZeroDivisionError:
    print("Invalid input. Input non-zero denominator")
# Out:
# Invalid input. Input non-zero denominator

# %% [markdown]
# # OBJECT ORIENTED PROGRAMMING

# %%
class DogClass():
    #class object attritube
    family = 'mammal'
    ##Attritubes
    def __init__(self,breed,color,size):
        self.whichbreed = breed
        self.whichcolor = color
        self.whatsize = size
        
    def bark(self):
        print("Dog Barks .. bhoo bhoow..my breed is {}".format(self.whichbreed))

# %%
thedog=DogClass(breed='Doberman',color='White',size='XL')
thedog.whichbreed
# Out:
# 'Doberman'

# %%
thedog.whichcolor
# Out:
# 'White'

# %%
thedog.whatsize
# Out:
# 'XL'

# %%
thedog.family
# Out:
# 'mammal'

# %% [markdown]
# # METHODS

# %%
thedog.bark()
# Out:
# Dog Barks .. bhoo bhoow..my breed is Doberman

# %%
class Circle():
    pi = 3.14

    def __init__(self,radius=1):
        self.radius = radius
        self.area = radius*radius*Circle.pi

    
    #method

    def get_circumference(self):
        return self.radius * Circle.pi * 2

# %%
mycircle = Circle(5)

# %%
mycircle.pi
# Out:
# 3.14

# %%
mycircle.radius
# Out:
# 5

# %%
mycircle.get_circumference()
# Out:
# 31.400000000000002

# %% [markdown]
# # INHERETANCE

# %%
class Animals():
    def __init__(self):
        print("ANIMAL CREATED")

    def whoami(self):
        print("I am Animal")

    def eat(self):
        print("I am eating")
    
class Dog(Animals):
    def __init__(self):
        Animals.__init__(self)
        print("DOg created")
    
    def eat(self):
        print("I am a dog eating")

    def bark(self):
        print("Woof")

# %%
mydog = Dog()
# Out:
# ANIMAL CREATED
# DOg created

# %%
mydog.bark()
# Out:
# Woof

# %% [markdown]
# # POLYMORPHISM

# %%
print(len("Younus"))
print(len([1,2,3]))
print(len({1,2,3,4}))
# Out:
# 6
# 3
# 4

# %%
class Dog():

    def __init__(self,name):
        self.name = name

    def speak(self):
        return self.name + " says woof!"
    

class Cat():
    def __init__(self,name):
        self.name = name

    def speak(self):
        return self.name + " says meow!"
    


niko: Dog = Dog(' Niko')
felix: Cat = Cat(' Felix')
                 
#print(niko.speak())
#print(felix.speak())



# Best Impementation by using FOR LoOP

for pet in [niko,felix]:
    print(type(pet))
    print(pet.speak())
    print("-------------")

#Another way is using the FUNCTION

def pet_speak(pet):
    print(pet.speak())

pet_speak(niko)
pet_speak(felix)
# Out:
# <class '__main__.Dog'>
#  Niko says woof!
# -------------
# <class '__main__.Cat'>
#  Felix says meow!
# -------------
#  Niko says woof!
#  Felix says meow!

# %%
from abc import ABC , abstractmethod

class PaymentType(ABC):
    @abstractmethod
    def process_payment(self,amount:float) -> None:
        ...

class CreditCard(PaymentType):
    def process_payment(self,amount:float) -> None:
        print(f'processing credit card payment of ${amount}')


class Cash(PaymentType):
    def process_payment(self,amount:float) -> None:
        print(f'processing Cash Payment of ${amount}')


class IOU(PaymentType):
    def process_payment(self,amount:float) -> None:
        print(f'processing IOU payment of ${amount}')

 

def checkout(payment_type: PaymentType,amount:float) -> None:
    payment_type.process_payment(amount)


credit_card: CreditCard = CreditCard()
cash: Cash = Cash()
iou: IOU = IOU()

checkout(credit_card,100)
checkout(cash,4000)
checkout(iou,1000)
# Out:
# processing credit card payment of $100
# processing Cash Payment of $4000
# processing IOU payment of $1000

# %% [markdown]
# # ABSTRACTION

# %%
class  Animals():
    def __init__(self,name):
        self.name=name
    
    def speak(self):
        raise NotImplementedError("Subclass must implement this abstract method")
    

class Dog(Animals):
    def speak(self):
        return self.name + "Says wooof.. woof"
    
class Cat(Animals):
    def speak(self):
        return self.name + "Says mewoo mwoo"

fido: Dog = Dog("Fido")
felix: Cat = Cat('Felix')

print(fido.speak())
print(felix.speak())
# Out:
# FidoSays wooof.. woof
# FelixSays mewoo mwoo

# %%
from abc import ABC,abstractmethod

class Animal(ABC):
    def __init__(self,name:str)-> None:
        self.name = name

    @abstractmethod
    def sound(self) -> None:
        ...

    @abstractmethod
    def move(self) -> None:
        ...


class Cat(Animal):
    def __init__(self,name:str)->None:
        super().__init__(name)
    
    def sound(self) -> None:
        print("Meow!")
    
    def move(self) -> None:
        print('Paw paw paw paw')

    
cat: Cat = Cat('SnowBall')
cat.sound()
cat.move()
# Out:
# Meow!
# Paw paw paw paw

# %% [markdown]
# # D U N D E R

# %%
class Account():
    def __init__(self,owner,balance=0):
        self.owner = owner
        self.balance = balance

    def deposit(self,dep_amt):
        self.balance = self.balance + dep_amt
        print(f"Added {dep_amt} to the balance")

    def withdrawal(self,wd_amt):
        if self.balance >=  wd_amt:
            self.balance -= wd_amt
            print("Withdrawl accepted")
        else:
            print('Sorry not enough funds!')

    def __str__(self):
        return f"onwer:{self.owner}\nBalance:{self.balance}"



a = Account = Account("Younus",5000)

print(a)
# Out:
# onwer:Younus
# Balance:5000

# %%
a.balance
# Out:
# 5000

# %%
a.deposit(100)
# Out:
# Added 100 to the balance

# %%
a.balance
# Out:
# 6100

# %%
a.withdrawal(6000)
# Out:
# Withdrawl accepted

# %%
a.balance
# Out:
# 100

# %%
a.withdrawal(100)
# Out:
# Withdrawl accepted

# %%
a.balance
# Out:
# 0

# %%
from colorama import init
init()
from colorama import Fore    
print(Fore.GREEN + "SOME RED TEXT")
# Out:
# SOME RED TEXT

# %%
import math
print(math.sqrt(16))   # Output: 4.0
# Out:
# 4.0

# %%
my_package/
    __init__.py
    module1.py
    module2.py
    sub_package/
        __init__.py
        module3.py
